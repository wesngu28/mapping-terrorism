# %%
import pandas as pd
from google.colab import drive

# %%
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
gtd = pd.read_csv('/content/gdrive/My Drive/Colab Notebooks/data/GTD.csv')

# %%
gtd.head()
# Out:
#         eventid  iyear  imonth  iday         country_txt           city  \
# 0  1.970000e+11   1970       7     2  Dominican Republic  Santo Domingo
# 1  1.970000e+11   1970       0     0              Mexico    Mexico city
# 2  1.970000e+11   1970       1     0         Philippines        Unknown
# 3  1.970000e+11   1970       1     0              Greece         Athens
# 4  1.970000e+11   1970       1     0               Japan        Fukouka
#
#     latitude   longitude  doubtterr                 attacktype1_txt  ...  \
# 0  18.456792  -69.951164          0                   Assassination  ...
# 1  19.371887  -99.086624          0     Hostage Taking (Kidnapping)  ...
# 2  15.478598  120.599741          0                   Assassination  ...
# 3  37.997490   23.762728          0               Bombing/Explosion  ...
# 4  33.580412  130.396361         -9  Facility/Infrastructure Attack  ...
#
#   nkill nwound property propextent_txt nhostkid ransom  scite1  scite2  \
# 0   1.0    0.0        0            NaN      NaN    0.0     NaN     NaN
# 1   0.0    0.0        0            NaN      1.0    1.0     NaN     NaN
# 2   1.0    0.0        0            NaN      NaN    0.0     NaN     NaN
# 3   NaN    NaN        1            NaN      NaN    0.0     NaN     NaN
# 4   NaN    NaN        1            NaN      NaN    0.0     NaN     NaN
#
#    scite3 dbsource
# 0     NaN     PGIS
# 1     NaN     PGIS
# 2     NaN     PGIS
# 3     NaN     PGIS
# 4     NaN     PGIS
#
# [5 rows x 26 columns]

# %%
# remove all rows where there was doubt of terrorism attack
gtd_no_doubt = gtd[gtd.doubtterr == 0]

# remove all entries with no deaths, wounded, property damage, or hostages
gtd_only_damage = gtd_no_doubt[(gtd_no_doubt.nkill > 0) | (gtd_no_doubt.nwound > 0) | (gtd_no_doubt.property == 1) | (gtd_no_doubt.nhostkid > 0)]

# remove all entries without sources
gtd_only_sources = gtd_only_damage[(pd.notna(gtd_only_damage.scite1)) | (pd.notna(gtd_only_damage.scite2)) | (pd.notna(gtd_only_damage.scite3))]
len(gtd_only_sources.index)
# Out:
# 95328

# %%
# filter the final columns
gtd_filtered = gtd_only_sources.filter(items=['iyear', 'imonth', 'iday', 'country_txt', 'city', 'latitude', 'longitude', 
                                              'attacktype1_txt', 'targtype1_txt', 'target1', 'gname', 'weaptype1_txt',
                                              'nkill', 'nwound', 'property', 'propextent_txt', 'nhostkid', 'ransom',
                                              'scite1', 'scite2', 'scite3', 'dbsource'])
gtd_filtered.head()
# Out:
#     iyear  imonth  iday    country_txt           city   latitude  longitude  \
# 5    1970       1     1  United States          Cairo  37.005105 -89.176269
# 8    1970       1     2  United States        Madison  43.076592 -89.412488
# 9    1970       1     3  United States        Madison  43.072950 -89.386694
# 13   1970       1     9  United States        Detroit  42.331685 -83.047924
# 17   1970       1    12  United States  New York City  40.697132 -73.931351
#
#                    attacktype1_txt            targtype1_txt  \
# 5                    Armed Assault                   Police
# 8   Facility/Infrastructure Attack                 Military
# 9   Facility/Infrastructure Attack     Government (General)
# 13  Facility/Infrastructure Attack     Government (General)
# 17               Bombing/Explosion  Educational Institution
#
#                                               target1  ... nkill nwound  \
# 5                           Cairo Police Headquarters  ...   0.0    0.0
# 8   R.O.T.C. offices at University of Wisconsin, M...  ...   0.0    0.0
# 9   Selective Service Headquarters in Madison Wisc...  ...   0.0    0.0
# 13    Packard Properties building of Detroit Michigan  ...   0.0    0.0
# 17                          James Madison High School  ...   0.0    0.0
#
#     property               propextent_txt  nhostkid ransom  \
# 5          1  Minor (likely < $1 million)       NaN    0.0
# 8          1  Minor (likely < $1 million)       NaN    0.0
# 9          1  Minor (likely < $1 million)       NaN    0.0
# 13         1  Minor (likely < $1 million)       NaN    0.0
# 17         1  Minor (likely < $1 million)       NaN    0.0
#
#                                                scite1  \
# 5   "Police Chief Quits," Washington Post, January...
# 8   Tom Bates, "Rads: The 1970 Bombing of the Army...
# 9   Committee on Government Operations United Stat...
# 13  Committee on Government Operations United Stat...
# 17  "Blast Damages Flatbush School," New York Time...
#
#                                                scite2  \
# 5   "Cairo Police Chief Quits; Decries Local 'Mili...
# 8   David Newman, Sandra Sutherland, and Jon Stewa...
# 9   Tom Bates, "Rads: The 1970 Bombing of the Army...
# 13  Christopher Hewitt, "Political Violence and Te...
# 17  Linda Greenhouse, "Madison School Puzzled By B...
#
#                                                scite3        dbsource
# 5   Christopher Hewitt, "Political Violence and Te...  Hewitt Project
# 8   The Wisconsin Cartographers' Guild, "Wisconsin...  Hewitt Project
# 9   David Newman, Sandra Sutherland, and Jon Stewa...  Hewitt Project
# 13                                                NaN  Hewitt Project
# 17  Committee on Government Operations United Stat...  Hewitt Project
#
# [5 rows x 22 columns]

# %%
gtd_filtered.to_csv(r'/content/gdrive/My Drive/Colab Notebooks/data/GTD_filtered.csv', index = False, header=True)
